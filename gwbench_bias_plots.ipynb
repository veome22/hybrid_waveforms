# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
import matplotlib


font = {'family' : 'serif',
        'size'   : 16}

matplotlib.rc('font', **font)

# %%
df = pd.read_csv('Mc_bias_uniform_statistics.csv')
df = df.loc[~(df==0).all(axis=1)]
df
# Out:
#          M_tot         q  full_bias           snr   Mc_stat_err  Mc_max_lam  \
# 0    88.697365  7.280173   0.053673  6.848362e+05  5.011628e-07    0.000100
# 1    93.235482  3.990652   0.153967  2.342176e+06  3.099921e-07    0.000100
# 2   126.932679  1.885208   0.817688  5.648689e+05  6.855483e-06    0.000100
# 3   101.446057  2.361173   0.461922  1.341045e+06  1.699558e-06    0.000100
# 4    96.053365  1.476616   0.348213  6.606704e+05  2.478787e-06    0.000100
# ..         ...       ...        ...           ...           ...         ...
# 67  104.159232  1.006568   0.430865  1.965721e+05  1.089235e-05    0.000288
# 68  141.635031  2.048707   1.372544  1.584651e+06  4.518654e-06    0.000100
# 69   15.929531  3.077217   0.000453  2.348857e+05  2.802695e-08    0.000509
# 70   92.250161  1.119544   0.340782  8.986062e+05  1.850400e-06    0.000100
# 71  122.815476  3.363684   0.507045  2.928718e+05  7.460611e-06    0.000100
#
#     Mc_min_faith
# 0            1.0
# 1            1.0
# ...

# %%
fig, ax = plt.subplots(figsize=(10, 7))
# cm = plt.cm.get_cmap('RdYlBu')
cm = plt.cm.get_cmap('GnBu')

sc = plt.scatter(df["M_tot"], 1/df["q"], c=df["Mc_min_faith"], cmap=cm, norm=matplotlib.colors.LogNorm())
cbar = plt.colorbar(sc)
cbar.set_label('Faithfulness')

plt.xlabel("M_tot")
plt.ylabel("1/q")
plt.title("Mc Waveform Faithfulness required")

plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 7))
# cm = plt.cm.get_cmap('RdYlBu')
cm = plt.cm.get_cmap('GnBu')

sc = plt.scatter(df["M_tot"], 1/df["q"], c=df["full_bias"]/df["Mc_stat_err"], cmap=cm, norm=matplotlib.colors.LogNorm())
cbar = plt.colorbar(sc)
cbar.set_label('bias / stat. err')

plt.xlabel("M_tot")
plt.ylabel("1/q")
plt.title("Mc Theoretical Bias \n IMRPhenomXAS vs IMRPhenomD")

plt.tight_layout()
plt.show()
